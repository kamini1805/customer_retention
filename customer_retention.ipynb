# %%
import pandas as pd
df=pd.read_csv("customer_retention_dataset5.csv")

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df['1Gender of respondent'].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
g = df.groupby("1Gender of respondent")
g

# %%
for gender, gender_df in g:
    print(gender)
# Out:
# Female
# Male

# %%
print(gender_df)
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 3                    Male         21-30 years
# 6                    Male         41-50 yaers
# 7                    Male         41-50 yaers
# 10                   Male         31-40 years
# ..                    ...                 ...
# 250                  Male         31-40 years
# 252                  Male         21-30 years
# 253                  Male         41-50 yaers
# 255                  Male         31-40 years
# 263                  Male         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 3                                 Karnal
# 6                                   Delhi
# 7                                   Delhi
# 10                              Moradabad
# ..                                    ...
# 250                                 Delhi
# 252                               Karnal
# ...

# %%
women=g.get_group('Female')

# %%
women
# Out:
#     1Gender of respondent 2 How old are you?   \
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 4                  Female         21-30 years
# 5                  Female         31-40 years
# 8                  Female  Less than 20 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 1                                   Delhi
# 2                           Greater Noida
# 4                              Bangalore
# 5                                   Noida
# 8                                   Solan
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
women.shape
# Out:
# (181, 71)

# %%
men=g.get_group('Male')
men.head()
# Out:
#    1Gender of respondent 2 How old are you?   \
# 0                   Male         31-40 years
# 3                   Male         21-30 years
# 6                   Male         41-50 yaers
# 7                   Male         41-50 yaers
# 10                  Male         31-40 years
#
#    3 Which city do you shop online from?  \
# 0                                  Delhi
# 3                                Karnal
# 6                                  Delhi
# 7                                  Delhi
# 10                             Moradabad
#
#     4 What is the Pin Code of where you shop online from?  \
# 0                                              110009
# 3                                              132001
# 6                                              110011
# 7                                              110018
# 10                                             244001
#
#    5 Since How Long You are Shopping Online ?  \
# 0                               Above 4 years
# ...

# %%
men.shape
# Out:
# (88, 71)

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
features=['1Gender of respondent', '2 How old are you? ','3 Which city do you shop online from?',
          'Wild variety of product on offer',
       'Complete, relevant description information of products',
       'Fast loading website speed of website and application',
       'Reliability of the website or application',
       'Quickness to complete purchase',
       'Availability of several payment options', 'Speedy order delivery ',
       'Privacy of customers? information',
       'Security of customer financial information',
       'Perceived Trustworthiness',
       'Presence of online assistance through multi-channel',
       'Longer time to get logged in (promotion, sales period)',
       'Late declaration of price (promotion, sales period)',
       'Longer page loading time (promotion, sales period)',
       'Limited mode of payment on most products (promotion, sales period)',
       'Longer delivery period', 'Change in website/Application design',
       'Frequent disruption when moving from one page to another',
       'Website is as efficient as before']

# %%
list(enumerate(features))
# Out:
# [(0, '1Gender of respondent'),
#  (1, '2 How old are you? '),
#  (2, '3 Which city do you shop online from?'),
#  (3, 'Wild variety of product on offer'),
#  (4, 'Complete, relevant description information of products'),
#  (5, 'Fast loading website speed of website and application'),
#  (6, 'Reliability of the website or application'),
#  (7, 'Quickness to complete purchase'),
#  (8, 'Availability of several payment options'),
#  (9, 'Speedy order delivery '),
#  (10, 'Privacy of customers? information'),
#  (11, 'Security of customer financial information'),
#  (12, 'Perceived Trustworthiness'),
#  (13, 'Presence of online assistance through multi-channel'),
#  (14, 'Longer time to get logged in (promotion, sales period)'),
#  (15, 'Late declaration of price (promotion, sales period)'),
#  (16, 'Longer page loading time (promotion, sales period)'),
#  (17, 'Limited mode of payment on most products (promotion, sales period)'),
#  (18, 'Longer delivery period'),
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (50,100))
for i in enumerate(features):
    plt.subplot(12,2,i[0]+1)
    sns.countplot(i[1], hue = 'Which of the Indian online retailer would you recommend to a friend?', data = df)
    plt.xticks(rotation = 45)

# %%
plt.figure(figsize=(8,5))
sns.countplot(["Shopping online is convenient and flexible"],data=df)
plt.ylabel('count', size=15)
plt.show()
